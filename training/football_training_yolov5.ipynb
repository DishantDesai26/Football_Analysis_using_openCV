# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/76.2 kB ? eta -:--:--
#    ------------------------------------- -- 71.7/76.2 kB ? eta -:--:--
#    ------------------------------------- -- 71.7/76.2 kB ? eta -:--:--
#    ---------------------------------------- 76.2/76.2 kB 467.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    -------------------------------------- - 174.1/178.7 kB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 178.7/178.7 kB 1.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ------------------------------------ --- 61.4/66.8 kB ? eta -:--:--
#    ------------------------------------ --- 61.4/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 514.5 kB/s eta 0:00:00
# ...

# %% [markdown]
# # Get Data Set

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ZSjv1VW2kywIIwbCZkCs")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:09<00:00, 145.91it/s]

# %%
dataset.location
# Out:
# 'c:\\Projects\\Football Analysis using CV\\training\\football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1/train', 
            'football-players-detection-1/football-players-detection-1')

shutil.move('football-players-detection-1/test', 
            'football-players-detection-1/football-players-detection-1')

shutil.move('football-players-detection-1/valid', 
            'football-players-detection-1/football-players-detection-1')
# Out:
# 'football-players-detection-1/football-players-detection-1\\valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yoylov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
